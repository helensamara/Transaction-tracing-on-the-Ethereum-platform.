# %%
import polars as pl
import pandas as pd
import numpy as np
import networkx as nx
import gravis as gv
import string

from utils import gv_defaults, filter_main_df_from_tx_hash, make_base_graph

import dataframe_image as dfi

# %%
load_df = pl.read_parquet("./data/0x4b0Aaf3EBb163dd45F663b38b6d93f6093EBC2d3.pqt")

# %%
xfers = load_df.filter(pl.col("type") == "transfer").select("hash").unique().sample(20)
swap = load_df.filter(pl.col("type") == "swap").select("hash").unique().sample(20)
compl = load_df.filter(pl.col("type").str.starts_with("non")).select("hash").unique().sample(20)

# %%
types = {
    "transfer": xfers,
    "swap"    : swap,
    "complex" : compl
}

hashes = {k:{} for k in types.keys()}
save_path = "./samples/{typ}/{idx}_{note}.{ext}"

for _typ, _sample in types.items():
    for idx in range(10):
        tx_hash = _sample[idx, "hash"]
        hashes[_typ][idx] = tx_hash
        
        _df, source_node = filter_main_df_from_tx_hash(load_df, tx_hash)
        
        for mask in (True, False):
            mask_note = "masked" if mask else "full"
            
            _G, fig = make_base_graph(_df, source_node=source_node, mask_non_ETH=mask)
            fig.export_html(
                save_path.format(
                    typ=_typ,
                    idx=idx,
                    note=f"base_{mask_note}",
                    ext="html"
                )
            )
            
        _df = _df[["from", "to", "value", "symbol"]]
        dfi.export(
            _df,
            save_path.format(
                typ=_typ,
                idx=idx,
                note="table",
                ext="png"
            )
        )

# %%
import json

print(json.dumps(hashes, indent=4))
# Out:
# {
#     "transfer": {
#         "0": "0x4ad791e5e94276c7022f753cf51652052e7a71b9ee2f38f8708d2021d5a3e972",
#         "1": "0x9e9bac3bbdd79c5990fa03f0c471dc591e248c1aefbe59598454b8679fedd61c",
#         "2": "0x0b4e51b82fcfd24afc537d51e70f789f293f74911dbaf74dbec2e79a60729fbe",
#         "3": "0x5f46f2ffea26e5798e12c6921ae51c6ccb4976dbcb65c72ece92b03fe4ea78db",
#         "4": "0x8d176a8b11711219366dbeffe6277836b66b75ce083dcc2be47bd1c0b718ce5a",
#         "5": "0x38d2f86c900f62b6970019d4cc1301612528efa132517008b3d1c44c66551536",
#         "6": "0x740ef8a2003e0dbd466b329fb34b44065197fad47cef75c8c3d4964eb66bbf3e",
#         "7": "0x072d3fca35fbfc750355ca0093e822c7f15abb52c17cc807bc0cbe5bd2f109b4",
#         "8": "0xb27869cb54adf24bc76a26759a7b2b18c793f3624ad1772f2b26bce7904e340b",
#         "9": "0x84797a713841e6401b69fcb15bf1113f50c572fb8eb29692a736966b2b5a3fe8"
#     },
#     "swap": {
#         "0": "0xa3212469df4dbae8e3bb4367da12375ff9644301d68ad67906774034771ef7b9",
#         "1": "0xbb7ae071be7d375a534f3fe4ada5ab590ddc79baa1b7353039f2ad76288656e6",
#         "2": "0x52a05925be62e5124f780bf2a9e5a1070e5bb902eae3a59ef92a395f9df647e4",
#         "3": "0x995b64f1c41ca47b14595c49907d7b64ee01390db6e62f1946032e065b662ac4",
#         "4": "0x801ffb90b615b751b1352ae4dab25943019890b939d10e7ea8d9d4f5f2f0a569",
#         "5": "0x1abc91b1695ccc53bb7632176f147a29d19c32d27a6755f88038c5c12ea73fb0",
#         "6": "0x7d2adaa160823f7c830a779cb681b3cb9a2cd19268594dee621ae9862b3a9b92",
#         "7": "0xba0fe24c7ca6425b95a1c7f7d72bb5e98687f4a25f6d4c1e70124ec702fa0364",
#         "8": "0xac99cf1a19f99aff68d2d00126f5ed67378a6fa239089c0eddc3ce9d3cead90a",
#         "9": "0xfcf1265f3a0e8bbdf079c00ae8a9a3f7b2dcbeb17f94ef32b7596b8db91ddd1b"
#     },
#     "complex": {
#         "0": "0xb72b66ca1726a7b03c1f508a5308ba03f2abc56131d95d6f3a83f241d719f9a4",
#         "1": "0xbf3c8990fadc0536f90b67169fc9dbcf9c7ef4542a2dd5e7a7140734610144b1",
#         "2": "0x2331c39396143a37cf7ea683a02ccffe28d7855472fca6100d956f1875ea4607",
#         "3": "0x38fa3a60c74f5ad04744070985c4ad3888f650dbe31062db4c699930ba0841c8",
#         "4": "0x337a50bb5e34b2dcbe647e2b994e5ccd1306c1b49ff71434a3c2c647b0e8aa32",
#         "5": "0x23039b3aa3bd439ff9f529793f65c1bf5d1e25373db9b0190c8008af52194626",
#         "6": "0x9630af4d3ace57d6a86b54c2e58a282186a169482a5de81d4f2fa256ae190a4b",
#         "7": "0xed42f2256790a1c696b9f362b4197061326b3f55326059e7ae08d079158c03b5",
#         "8": "0x6711ea74d6b8c09d66b0162f14e72094ca6bca2b7a17e0b57943595248980199",
#         "9": "0x8f8c4572910f02929f40a059632a9c8018a873f20a28471e89aba609e95d96f5"
#     }
# }

# %%
with open('./samples/hashes.json', 'w') as f:
    json.dump(hashes, f)
